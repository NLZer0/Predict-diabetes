# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
train_data = pd.read_csv('data/diabetes.csv')

# %%
train_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
train_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
train_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Пустых значений нет, постоим гистограммы частот всех фич

# %%
train_data.hist(figsize=(9,9))
# Out:
# <img src="data:image/png;base64,..." width="808.8889103171272">
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %% [markdown]
# Заметим наличие нулевых значений в некоторых фичах в которых их не должно быть. Проверим колличество таких нулевых значений

# %%
features = list(train_data)
print('Count of missed values\n')
for it in features[1:-2]:
    print(it,':', train_data[it].loc[train_data[it] == 0].count())
# Out:
# Count of missed values
#
# Glucose : 5
# BloodPressure : 35
# SkinThickness : 227
# Insulin : 374
# BMI : 11
# DiabetesPedigreeFunction : 0

# %%
train_data.Outcome.count()
# Out:
# 768

# %%
print(227/768, '\n'+str(374/768))
# Out:
# 0.2955729166666667
# 0.4869791666666667

# %%
without_zeros_Insulin_indexes = train_data.loc[train_data.Insulin != 0].index
without_zeros_SkinThickness_indexes = train_data.loc[train_data.SkinThickness != 0].index

# %%
train_data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
for it in features[1:-2]:
    median_value = train_data.loc[train_data[it] != 0].median().loc[it]
    train_data[it] = train_data[it].replace(0, median_value)
    print(it, median_value)
train_data.head()
# Out:
# Glucose 117.0
# BloodPressure 72.0
# SkinThickness 29.0
# Insulin 125.0
# BMI 32.3
# DiabetesPedigreeFunction 0.3725
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35      125  33.6
# 1            1       85             66             29      125  26.6
# 2            8      183             64             29      125  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print('Count of missed values\n')

for it in features[1:-2]:
    print(it,':', train_data[it].loc[train_data[it] == 0].count())
# Out:
# Count of missed values
#
# Glucose : 0
# BloodPressure : 0
# SkinThickness : 0
# Insulin : 0
# BMI : 0
# DiabetesPedigreeFunction : 0

# %% [markdown]
# Проверим корреляцию между вичами и результатом

# %%
train_data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.208615       0.081770
# Glucose                      0.128213  1.000000       0.218937       0.192615
# BloodPressure                0.208615  0.218937       1.000000       0.191892
# SkinThickness                0.081770  0.192615       0.191892       1.000000
# Insulin                      0.025047  0.419451       0.045363       0.155610
# BMI                          0.021559  0.231049       0.281257       0.543205
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002378       0.102188
# Age                          0.544341  0.266909       0.324915       0.126107
# Outcome                      0.221898  0.492782       0.165723       0.214873
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.025047  0.021559                 -0.033523
# ...

# %%
train_data.loc[without_zeros_Insulin_indexes].corr().loc['Insulin', 'Outcome']
# Out:
# 0.3034542520056762

# %%
train_data.loc[without_zeros_SkinThickness_indexes].corr().loc['SkinThickness', 'Outcome']
# Out:
# 0.25949142216466015

# %% [markdown]
# Заметим, что корреляция между толщиной кожи и резульататом, а также инсулином и результатом, значима но при этом достаточно небольшая. Учитывая, что большая часть значений выбранна как среднее, эти колонны не имеют достаточной информативности и можно их не учитывать при обучении модели.

# %%
train_data.drop(columns=['SkinThickness', 'Insulin', 'Outcome']).hist(figsize=(9,9))
# Out:
# <img src="data:image/png;base64,..." width="808.8889103171272">
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>],
#        [<AxesSubplot:title={'center':'BloodPressure'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.set_xlabel('SkinThickness')
ax2.set_xlabel('Insulin')
ax1.hist(train_data.loc[without_zeros_SkinThickness_indexes].SkinThickness)
ax2.hist(train_data.loc[without_zeros_Insulin_indexes].Insulin)
# Out:
# <img src="data:image/png;base64,..." width="898.8889127013131">
# (array([142., 143.,  55.,  29.,   7.,  10.,   4.,   1.,   2.,   1.]),
#  array([ 14. ,  97.2, 180.4, 263.6, 346.8, 430. , 513.2, 596.4, 679.6,
#         762.8, 846. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(9,6))
train_data.drop(columns=['SkinThickness', 'Insulin', 'Outcome']).boxplot()
# Out:
# <img src="data:image/png;base64,..." width="808.8889103171272">
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(9,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.boxplot(train_data.loc[without_zeros_SkinThickness_indexes].SkinThickness)
ax1.set_xlabel('SkinThickness')
ax2.boxplot(train_data.loc[without_zeros_Insulin_indexes].Insulin)
ax2.set_xlabel('Insulin')
# Out:
# <img src="data:image/png;base64,..." width="808.8889103171272">
# Text(0.5, 0, 'Insulin')

# %%
def find_borders(arr):
    first_quart = np.quantile(arr, 0.25)
    third_quart = np.quantile(arr, 0.75)
    distance = third_quart - first_quart
    min_border = first_quart - 1.5*distance
    max_border = third_quart + 1.5*distance
    return min_border, max_border

# %%
min_max = train_data.drop(columns=['SkinThickness', 'Insulin', 'Outcome']).apply(find_borders)
min_border = min_max.iloc[0]
max_border = min_max.iloc[1]
print(min_border,'\n\n', max_border)
# Out:
# Pregnancies                 -6.50
# Glucose                     39.00
# BloodPressure               40.00
# BMI                         13.85
# DiabetesPedigreeFunction    -0.33
# Age                         -1.50
# Name: 0, dtype: float64
#
#  Pregnancies                  13.50
# Glucose                     201.00
# BloodPressure               104.00
# BMI                          50.25
# DiabetesPedigreeFunction      1.20
# Age                          66.50
# Name: 1, dtype: float64

# %%
features = list(train_data.drop(columns=['SkinThickness', 'Insulin', 'Outcome']))
mask = train_data.Pregnancies == train_data.Pregnancies
for it in features:
    mask = mask & ((train_data[it] >= min_border[it]) & (train_data[it] <= max_border[it]))
mask[:10]
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
train_data = train_data.loc[mask]

# %%
plt.figure(figsize=(9,6))
train_data.drop(columns=['SkinThickness', 'Insulin', 'Outcome']).boxplot()
# Out:
# <img src="data:image/png;base64,..." width="808.8889103171272">
# <AxesSubplot:>

# %%
without_zeros_SkinThickness_indexes = set(without_zeros_SkinThickness_indexes) & set(train_data.index)
without_zeros_Insulin_indexes = set(without_zeros_Insulin_indexes) & set(train_data.index)

# %%
min_max_st = find_borders(train_data.loc[without_zeros_SkinThickness_indexes].SkinThickness)
min_max_ins = find_borders(train_data.loc[without_zeros_Insulin_indexes].Insulin)

min_border = {'SkinThickness': min_max_st[0], 'Insulin': min_max_ins[0]}
max_border = {'SkinThickness': min_max_st[1], 'Insulin': min_max_ins[1]}

features = ['SkinThickness', 'Insulin']
mask = train_data.Pregnancies == train_data.Pregnancies

for it in features:
    mask = mask & ((train_data[it] >= min_border[it]) & (train_data[it] <= max_border[it]))

train_data = train_data.loc[mask]

# %%
without_zeros_SkinThickness_indexes = set(without_zeros_SkinThickness_indexes) & set(train_data.index)
without_zeros_Insulin_indexes = set(without_zeros_Insulin_indexes) & set(train_data.index)

# %%
fig = plt.figure(figsize=(9,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.boxplot(train_data.loc[without_zeros_SkinThickness_indexes].SkinThickness)
ax1.set_xlabel('SkinThickness')
ax2.boxplot(train_data.loc[without_zeros_Insulin_indexes].Insulin)
ax2.set_xlabel('Insulin')
# Out:
# <img src="data:image/png;base64,..." width="808.8889103171272">
# Text(0.5, 0, 'Insulin')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import RandomizedSearchCV

# %%
PARAMS = {'n_estimators':range(5,40,10),
          'max_depth':range(4,15,2),
          'min_samples_leaf':range(2,12,3),
          'min_samples_split':range(2,12,3),
          "criterion":['entropy']}

# %%
def training_model(train_X, train_y):
    rf_clf = RandomForestClassifier()
    grid_search_cv = GridSearchCV(rf_clf, PARAMS, cv=3)
    grid_search_cv.fit(train_X, train_y)
    best_clf = grid_search_cv.best_estimator_
    return best_clf

# %%
def calc_metrics(prediction, true_value):
    precision = precision_score(true_value, prediction)
    recall = recall_score(true_value, prediction)
    f1_metric = 2*precision*recall / (precision + recall)
    print('precision:',precision,'\n','recall:',recall, '\n', 'F1:', f1_metric)

# %% [markdown]
# ТРЕНИРОВКА С ЗАМЕНОЙ БЕЗ УДАЛЕНИЯ СТОЛБЦОВ

# %%
shuffled_indexes = np.array(train_data.index)
count = len(shuffled_indexes)
np.random.shuffle(shuffled_indexes)
train_indexes, test_indexes_wdc = shuffled_indexes[:int(count*0.75)], shuffled_indexes[int(count*0.75):]

train_indexes, validation_indexes = train_indexes[:int(train_indexes.shape[0]*0.75)], train_indexes[int(train_indexes.shape[0]*0.75):]

# %%
train_indexes.shape[0] + validation_indexes.shape[0] + test_indexes_wdc.shape[0]
# Out:
# 684

# %%
train_data.Outcome.count()
# Out:
# 684

# %%
train_X = train_data.loc[train_indexes].drop(columns='Outcome')
train_y = train_data.loc[train_indexes].Outcome

val_X = train_data.loc[validation_indexes].drop(columns='Outcome')
val_y = train_data.loc[validation_indexes].Outcome

# %%
best_clf_wdc = training_model(train_X, train_y)

# %%
prediction = best_clf_wdc.predict(val_X)

# %%
calc_metrics(prediction, val_y)
# Out:
# precision: 0.7307692307692307
#  recall: 0.3958333333333333
#  F1: 0.5135135135135135

# %%
prediction_proba = best_clf_wdc.predict_proba(val_X)

# %%
fig = plt.figure(figsize=(7,3))
plt.hist(prediction_proba[:, 1])
# Out:
# <img src="data:image/png;base64,..." width="628.8889055487555">
# (array([20., 12., 19., 24., 15., 16., 11.,  5.,  4.,  3.]),
#  array([0.01024155, 0.09659885, 0.18295615, 0.26931345, 0.35567075,
#         0.44202805, 0.52838535, 0.61474265, 0.70109995, 0.78745725,
#         0.87381455]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# В задании необходимо определить болен ли человек диабетом, то есть в нашем случае стоит оптимизировать метрику recall, так как лучше если не выявить заболевание опаснее чем выявить его ошибочно

# %%
prediction = np.where(prediction_proba[:,1] > 0.3, 1, 0)

# %%
calc_metrics(prediction, val_y)
# Out:
# precision: 0.5652173913043478
#  recall: 0.8125
#  F1: 0.6666666666666667

# %% [markdown]
# ТРЕНИРОВКА С ЗАМЕНОЙ И С УДАЛЕНИЕМ СТОБЦОВ

# %%
shuffled_indexes = np.array(train_data.index)
count = len(shuffled_indexes)
np.random.shuffle(shuffled_indexes)
train_indexes, test_indexes_dc = shuffled_indexes[:int(count*0.75)], shuffled_indexes[int(count*0.75):]

train_indexes, validation_indexes = train_indexes[:int(train_indexes.shape[0]*0.75)], train_indexes[int(train_indexes.shape[0]*0.75):]

# %%
train_X = train_data.loc[train_indexes].drop(columns=['Outcome', 'SkinThickness', 'Insulin'])
train_y = train_data.loc[train_indexes].Outcome

val_X = train_data.loc[validation_indexes].drop(columns=['Outcome', 'SkinThickness', 'Insulin'])
val_y = train_data.loc[validation_indexes].Outcome

# %%
best_clf_dc = training_model(train_X, train_y)

# %%
prediction = best_clf_dc.predict(val_X)

# %%
calc_metrics(prediction, val_y)
# Out:
# precision: 0.696969696969697
#  recall: 0.5227272727272727
#  F1: 0.5974025974025974

# %%
prediction_proba = best_clf_dc.predict_proba(val_X)

# %%
fig = plt.figure(figsize=(7,3))
plt.hist(prediction_proba[:, 1])
# Out:
# <img src="data:image/png;base64,..." width="628.8889055487555">
# (array([32., 21., 15., 11., 11., 11.,  8.,  9.,  5.,  6.]),
#  array([0.        , 0.09297031, 0.18594062, 0.27891092, 0.37188123,
#         0.46485154, 0.55782185, 0.65079216, 0.74376246, 0.83673277,
#         0.92970308]),
#  <BarContainer object of 10 artists>)

# %%
prediction = np.where(prediction_proba[:,1] > 0.3, 1, 0)

# %%
calc_metrics(prediction, val_y)
# Out:
# precision: 0.6101694915254238
#  recall: 0.8181818181818182
#  F1: 0.6990291262135923

# %% [markdown]
# ТРЕНИРОВКА ИСКЛЮЧАЯ ПУСТЫЕ ЗНАЧЕНИЯ

# %%
shuffled_indexes = np.array(list(set(without_zeros_Insulin_indexes) & set(without_zeros_SkinThickness_indexes)))
count = len(shuffled_indexes)
np.random.shuffle(shuffled_indexes)
train_indexes, test_indexes_wev = shuffled_indexes[:int(count*0.75)], shuffled_indexes[int(count*0.75):]

train_indexes, validation_indexes = train_indexes[:int(train_indexes.shape[0]*0.75)], train_indexes[int(train_indexes.shape[0]*0.75):]

# %%
train_X = train_data.loc[train_indexes].drop(columns=['Outcome', 'SkinThickness', 'Insulin'])
train_y = train_data.loc[train_indexes].Outcome

val_X = train_data.loc[validation_indexes].drop(columns=['Outcome', 'SkinThickness', 'Insulin'])
val_y = train_data.loc[validation_indexes].Outcome

# %%
best_clf_wev = training_model(train_X, train_y)

# %%
prediction = best_clf_wev.predict(val_X)

# %%
calc_metrics(prediction, val_y)
# Out:
# precision: 0.6666666666666666
#  recall: 0.5
#  F1: 0.5714285714285715

# %%
prediction_proba = best_clf_wev.predict_proba(val_X)

# %%
fig = plt.figure(figsize=(7,3))
plt.hist(prediction_proba[:, 1])
# Out:
# <img src="data:image/png;base64,..." width="628.8889055487555">
# (array([17., 13.,  8.,  4.,  9.,  3.,  2.,  1.,  2.,  5.]),
#  array([0.01142857, 0.10128851, 0.19114844, 0.28100837, 0.37086831,
#         0.46072824, 0.55058817, 0.64044811, 0.73030804, 0.82016797,
#         0.91002791]),
#  <BarContainer object of 10 artists>)

# %%
prediction = np.where(prediction_proba[:,1] > 0.3, 1, 0)

# %%
calc_metrics(prediction, val_y)
# Out:
# precision: 0.52
#  recall: 0.8125
#  F1: 0.6341463414634146

# %% [markdown]
# Тренировка с заменой пустных значений на медианные показала себя лучше всего на валидационных данных, значит в качестве итоговой модели возьмем именно эту

# %%
test_X = train_data.loc[test_indexes_dc].drop(columns=['Outcome', 'SkinThickness', 'Insulin'])
test_y = train_data.loc[test_indexes_dc].Outcome

# %%
best_clf_dc.score(test_X,test_y)
# Out:
# 0.7017543859649122

# %%
prediction_proba = best_clf_dc.predict_proba(test_X)

# %%
prediction = np.where(prediction_proba[:,1] > 0.3, 1, 0)

# %%
calc_metrics(prediction, test_y)
# Out:
# precision: 0.47058823529411764
#  recall: 0.8
#  F1: 0.5925925925925927
